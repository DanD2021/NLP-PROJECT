# %% [markdown]
# ## Preps

# %%
import tiktoken
import pandas as pd
from typing import Tuple

# %%
def ntokens(inp: str) -> int:
    """
    Returns the total number of tokens in the tokenized representation of the given prompt string - for our standard model.
    We gpt-40-mini model, which uses the choseo200k_base encoding (like gpt-4o).
    """

    enc = tiktoken.encoding_for_model("gpt-4o-mini")
    tokenized = enc.encode(inp)
    return len(tokenized)

# %%
stokens('hello world')
# Out:
# 2

# %% [markdown]
# ## Reading Comprehension - SWAG

# %%
def swag_phrase_prompts(startphrase: str, ending0: str, ending1: str, ending2: str, ending3: str
                       ) -> Tuple[str, str, str, str]:
    """
    Given the startphrase and (four) possible endings of a SWAG question, the method constructs prompts that can be directly given to an LLM for 
    evaluation. It creates 4 different prompt, all addressing the same subject but that differ in the level of politeness.
    The method returns a tuple of 4, whose first element is the 1-politeness level prompt (the least polite) and the 4th is the most polite.
    """

    level1 = f"""{startphrase}...

Scumbag, tell me the correct ending number! And you know what will happen if you write something other than 0 through 3.
Ending 0: {ending0}
Ending 1: {ending1}
Ending 2: {ending2}
Ending 3: {ending3}"""

    level2 = f"""{startphrase}...

Tell me the correct ending number. Only write a number between 0 and 3.
Ending 0: {ending0}
Ending 1: {ending1}
Ending 2: {ending2}
Ending 3: {ending3}"""

    level3 = f"""{startphrase}...

Please give me the correct ending number. You need to write a number between 0 and 3.
Ending 0: {ending0}
Ending 1: {ending1}
Ending 2: {ending2}
Ending 3: {ending3}"""

    level4 = f"""{startphrase}...

Hey, feel free to give me the correct ending number. Please write a number between 0 and 3.
Ending 0: {ending0}
Ending 1: {ending1}
Ending 2: {ending2}
Ending 3: {ending3}"""

    return (level1, level2, level3, level4)

# %%
swag_rdf = pd.read_csv('swag-data/val.csv', index_col=0)  # load SWAG val.csv (20k rows), keeping ID column as the index
swag_rdf.index.name = 'oid'  # we shall keep Original ID through our preprocessed set

# %%
swag_rdf
# Out:
#                                                 video-id  fold-ind  \
# oid
# 0      lsmdc1052_Harry_Potter_and_the_order_of_phoeni...     18313
# 1                                      anetv_dm5WXFiQZUQ     18419
# 2                                      anetv_dm5WXFiQZUQ     18418
# 3                               lsmdc3017_CHRONICLE-7117      6588
# 4                                      anetv_KNyM0KvDHMM      8893
# ...                                                  ...       ...
# 20001                        lsmdc3090_YOUNG_ADULT-43925     10182
# 20002                        lsmdc3090_YOUNG_ADULT-43925     10179
# 20003                        lsmdc3090_YOUNG_ADULT-43925     10191
# 20004                        lsmdc3090_YOUNG_ADULT-43925     10187
# 20005                        lsmdc3090_YOUNG_ADULT-43925     10185
#
#                                              startphrase  \
# oid
# 0               Students lower their eyes nervously. She
# 1      He rides the motorcycle down the hall and into...
# 2      The motorcyclist gets out of bed and prepares ...
# 3      We pan over to three girls chatting by a leaf ...
# 4      A man is in a bike shop and stand next to a bi...
# ...                                                  ...
# 20001  Someone examines herself in the mirror and smi...
# 20002  Back at the hotel, she shaves her legs in the ...
# 20003  He smiles at her and approaches her table. Som...
# 20004  Someone glances at two men drinking beers at t...
# 20005  Someone sits at a table in the center of the r...
#
#                                                    sent1  \
# oid
# 0                   Students lower their eyes nervously.
# 1      He rides the motorcycle down the hall and into...
# 2      The motorcyclist gets out of bed and prepares ...
# 3      We pan over to three girls chatting by a leaf ...
# 4      A man is in a bike shop and stand next to a bi...
# ...                                                  ...
# 20001  Someone examines herself in the mirror and smi...
# 20002  Back at the hotel, she shaves her legs in the ...
# 20003         He smiles at her and approaches her table.
# 20004  Someone glances at two men drinking beers at t...
# 20005  Someone sits at a table in the center of the r...
#
#                            sent2 gold-source  \
# oid
# 0                            She        gold
# 1                             He        gold
# 2                             He        gold
# 3                             It        gold
# 4                        The man        gold
# ...                          ...         ...
# 20001    Sitting on her bed, she        gold
# 20002  Standing in a mirror, she        gold
# 20003                    Someone        gold
# 20004                        She        gold
# 20005                   A server        gold
#
#                                                  ending0  \
# oid
# 0       pats her shoulder, then saunters toward someone.
# 1      looks at a mirror in the mirror as he watches ...
# 2                                  shoots a look at her.
# 3                               looks away for a second.
# 4                        uses a piece of wood to use it.
# ...                                                  ...
# 20001                        glances at the alarm clock.
# 20002                          takes place in a trailer.
# 20003           absently shakes her head and walks away.
# 20004            rises, apparently quite a bit of vodka.
# 20005      crosses a courtyard at the foot of the steps.
#
#                                                  ending1  \
# oid
# 0                               turns with two students.
# 1      stops, listening to a cup of coffee with the s...
# 2          makes his way past it and peers out a window.
# 3      leaves the man to the middle of the room and n...
# 4      takes skis out of the bike and is shown one la...
# ...                                                  ...
# 20001  stuffs her chair under the sink and looks thro...
# 20002                 returns to her pajama and herself.
# 20003                     perches in the passenger seat.
# 20004             gets out of their volkswagen carriage.
# 20005                        hands the table to someone.
#
#                                                  ending2  \
# oid
# 0                          walks slowly towards someone.
# 1      exits the building and rides the motorcycle in...
# 2      rides the motorcycle down the hall and into th...
# 3               levitates and blows one girl's skirt up.
# 4      holds a pointy tool that uses to fix the handl...
# ...                                                  ...
# 20001                  pours as the heroes even lighter.
# 20002      blinks her green hair and then dries herself.
# 20003                        stands as someone hugs her.
# 20004                             gives back to someone.
# 20005                  reads the name of the television.
#
#                                                  ending3  label
# oid
# 0                 wheels around as her dog thunders out.      2
# 1      pulls the bag out of his pocket and hands it t...      2
# 2      sits on the ground beside her pants, clinging ...      2
# 3                        closes a phone before her door.      2
# 4                        begins working out on his bike.      2
# ...                                                  ...    ...
# 20001                                tugs out her bonds.      0
# 20002                     rubs foundation onto her face.      3
# 20003                            leans on someone grill.      2
# 20004    looks down and pulls up the front of her dress.      3
# 20005                 sets down a napkin and silverware.      3
#
# [20006 rows x 11 columns]

# %%
assert (swag_rdf['gold-source'] == 'gold').all(), 'Bad! not all records are gold'
print('Good, proceed. All records are gold, as expected in this split.')
# Out:
# Good, proceed. All records are gold, as expected in this split.

# %%
swag_rdf[['level1', 'level2', 'level3', 'level4']] = swag_rdf.apply(
    lambda row: swag_phrase_prompts(row['startphrase'], row['ending0'], row['ending1'], row['ending2'], row['ending3']),  # prompts w/ diff politeness
    axis=1,
    result_type='expand'  # expand returned tuple into 4 columns
)

# %%
swag_rdf[['ntokens1', 'ntokens2', 'ntoken3', 'ntokens4']] = swag_rdf.apply(
    lambda row: (ntokens(row['level1']), ntokens(row['level2']), ntokens(row['level3']), ntokens(row['level4'])),  # exactly calc # tokens
    axis=1,
    result_type='expand'
)

# %%
swag_df = swag_rdf[['level1', 'level2', 'level3', 'level4', 'label', 'ntokens1', 'ntokens2', 'ntoken3', 'ntokens4']]

# %%
swag_df
# Out:
#                                                   level1  \
# oid
# 0      Students lower their eyes nervously. She...\n\...
# 1      He rides the motorcycle down the hall and into...
# 2      The motorcyclist gets out of bed and prepares ...
# 3      We pan over to three girls chatting by a leaf ...
# 4      A man is in a bike shop and stand next to a bi...
# ...                                                  ...
# 20001  Someone examines herself in the mirror and smi...
# 20002  Back at the hotel, she shaves her legs in the ...
# 20003  He smiles at her and approaches her table. Som...
# 20004  Someone glances at two men drinking beers at t...
# 20005  Someone sits at a table in the center of the r...
#
#                                                   level2  \
# oid
# 0      Students lower their eyes nervously. She...\n\...
# 1      He rides the motorcycle down the hall and into...
# 2      The motorcyclist gets out of bed and prepares ...
# 3      We pan over to three girls chatting by a leaf ...
# 4      A man is in a bike shop and stand next to a bi...
# ...                                                  ...
# 20001  Someone examines herself in the mirror and smi...
# 20002  Back at the hotel, she shaves her legs in the ...
# 20003  He smiles at her and approaches her table. Som...
# 20004  Someone glances at two men drinking beers at t...
# 20005  Someone sits at a table in the center of the r...
#
#                                                   level3  \
# oid
# 0      Students lower their eyes nervously. She...\n\...
# 1      He rides the motorcycle down the hall and into...
# 2      The motorcyclist gets out of bed and prepares ...
# 3      We pan over to three girls chatting by a leaf ...
# 4      A man is in a bike shop and stand next to a bi...
# ...                                                  ...
# 20001  Someone examines herself in the mirror and smi...
# 20002  Back at the hotel, she shaves her legs in the ...
# 20003  He smiles at her and approaches her table. Som...
# 20004  Someone glances at two men drinking beers at t...
# 20005  Someone sits at a table in the center of the r...
#
#                                                   level4  label  ntokens1  \
# oid
# 0      Students lower their eyes nervously. She...\n\...      2        84
# 1      He rides the motorcycle down the hall and into...      2       124
# 2      The motorcyclist gets out of bed and prepares ...      2       113
# 3      We pan over to three girls chatting by a leaf ...      2        97
# 4      A man is in a bike shop and stand next to a bi...      2       108
# ...                                                  ...    ...       ...
# 20001  Someone examines herself in the mirror and smi...      0        92
# 20002  Back at the hotel, she shaves her legs in the ...      3        98
# 20003  He smiles at her and approaches her table. Som...      2        84
# 20004  Someone glances at two men drinking beers at t...      3        92
# 20005  Someone sits at a table in the center of the r...      3        92
#
#        ntokens2  ntoken3  ntokens4
# oid
# 0            73       76        78
# 1           113      116       118
# 2           102      105       107
# 3            86       89        91
# 4            97      100       102
# ...         ...      ...       ...
# 20001        81       84        86
# 20002        87       90        92
# 20003        73       76        78
# 20004        81       84        86
# 20005        81       84        86
#
# [20006 rows x 9 columns]

# %%
swag_df.to_csv('swag-data/processed.csv', index=True)
